# %% [markdown]
# <a href="https://colab.research.google.com/github/karendu8180/Data612/blob/main/Assignment_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment for Week 7

# %% [markdown]
# ## Purpose
# This assignment is intended to help you do the following:
#   - Groupby operations to aggregate, transform, and filter data
#   - Built-in and custom user functions to perform groupby operations

# %% [markdown]
# ## About the assignment
#
# In the industry, analytics professionals often explore data's measure variables grouped by one or multiple dimension variables. For example, the metrics of interest could be the average, max, min, or percentage (mix) of sales by month, location, etc.
#
# The followings are the sample code snippet using the custom user functions together with `groupby()` and `apply()` in another way:

# %%
import pandas as pd

# the mpg data is used for demonstration
df = pd.read_csv("https://raw.githubusercontent.com/franklin-univ-data-science/data/master/mpg.csv")
df.head()
# Out:
#     mpg  cylinders  displacement  acceleration  model  origin
# 0  18.0          8         307.0          12.0     70       1
# 1  15.0          8         350.0          11.5     70       1
# 2  18.0          8         318.0          11.0     70       1
# 3  16.0          8         304.0          12.0     70       1
# 4  17.0          8         302.0          10.5     70       1

# %%
def summarize_data(g):
  return(
    pd.Series({
      "avg_MPG": g.mpg.mean(),
      "min_MPG": g.mpg.min(),
      "max_MPG": g.mpg.max(),
      "sample_count": len(g),
      "mix": g.cylinders.sum()/df.cylinders.sum(),
    })
  )

df.groupby("cylinders").apply(summarize_data)
# Out:
#              avg_MPG  min_MPG  max_MPG  sample_count       mix
# cylinders
# 3          20.550000     18.0     23.7           4.0  0.005398
# 4          29.286765     18.0     46.6         207.0  0.372470
# 5          27.366667     20.3     36.4           3.0  0.006748
# 6          19.985714     15.0     38.0          84.0  0.226721
# 8          14.963107      9.0     26.6         108.0  0.388664

# %% [markdown]
# ## Tasks
#   1. Read the `summarize_data()` and explain the difference between g and df.
#
#   2. Select the measure and dimention variables from your dataframe, apply the `summarize_data()` and modify as needed based on your preferences.
#
#   3. Write 1-3 paragraphs to explain the differences or challenges when you applied the function to your chosen dataframe.
#
#   4. Post your version of the above code on your GitHub account. Do not forget a README file with explanations.

# %% [markdown]
# ## 1. Read the summarize_data() and explain the difference between g and df.
#
# df is showing all of the variables and collected data from the given data set, which included mpg, cylinders, displacement, acceleration, model, origin. g is only showing the more detailed collected data for the variable "cylinders". g is group the data by different cylinders variable, and contains the data of the average, minimum, maximum, count, and sum of cylinders in g/sum of cylinders in df.

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/frankData612/data_612/master/baseballdatabank-master/core/Salaries.csv")
df.head()
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000

# %%
# 2. Select the measure and dimention variables from your dataframe, apply the summarize_data() and modify as needed based on your preferences.

def summarize_data_2(f):#summerize the data for salary
  return(
    pd.Series({
      "avg_salary": f.salary.mean(),
      "min_salary": f.salary.min(),
      "max_salary": f.salary.max(),
      "sample_count": len(f),
      "mix": f.teamID.count()/df.teamID.count(),
    })
  )
df.groupby("teamID").apply(summarize_data_2) #groupby teamID
# Out:
#           avg_salary  min_salary  max_salary  sample_count       mix
# teamID
# ANA     1.895109e+06    150000.0  13166667.0         247.0  0.009346
# ARI     2.521796e+06    170000.0  31799030.0         539.0  0.020395
# ATL     2.211176e+06     60000.0  16061802.0         915.0  0.034622
# BAL     2.028839e+06     60000.0  21268890.0         940.0  0.035568
# BOS     2.968591e+06     60000.0  30000000.0         944.0  0.035720
# CAL     7.390732e+05     60000.0   5375000.0         368.0  0.013925
# CHA     2.168060e+06     50000.0  17000000.0         888.0  0.033601
# CHN     2.353348e+06     60000.0  25000000.0         905.0  0.034244
# CIN     1.759987e+06     60000.0  20000000.0         930.0  0.035190
# CLE     1.651203e+06     60000.0  15000000.0         949.0  0.035909
# COL     2.133870e+06    109000.0  22000000.0         704.0  0.026638
# DET     2.386561e+06     60000.0  28000000.0         896.0  0.033903
# ...

# %%
def summarize_data_2(f):#summerize the data for salary
  return(
    pd.Series({
      "avg_salary": f.salary.mean(),
      "min_salary": f.salary.min(),
      "max_salary": f.salary.max(),
      "sample_count": len(f),
      "mix": f.yearID.sum()/df.yearID.sum(),
    })
  )
df.groupby("yearID").apply(summarize_data_2) #groupby yearID
# Out:
#           avg_salary  min_salary  max_salary  sample_count       mix
# yearID
# 1985    4.762994e+05     60000.0   2130300.0         550.0  0.020646
# 1986    4.171470e+05     60000.0   2800000.0         738.0  0.027717
# 1987    4.347295e+05     62500.0   2127333.0         627.0  0.023560
# 1988    4.531711e+05     62500.0   2340000.0         663.0  0.024926
# 1989    5.063231e+05     62500.0   2766667.0         711.0  0.026744
# 1990    5.119737e+05    100000.0   3200000.0         867.0  0.032628
# 1991    8.949612e+05    100000.0   3800000.0         685.0  0.025792
# 1992    1.047521e+06    109000.0   6100000.0         769.0  0.028969
# 1993    9.769666e+05         0.0   6200000.0         923.0  0.034788
# 1994    1.049589e+06     50000.0   6300000.0         884.0  0.033334
# 1995    9.649791e+05    109000.0   9237500.0         986.0  0.037199
# 1996    1.027909e+06    109000.0   9237500.0         931.0  0.035142
# ...

# %% [markdown]
# # 3. Write 1-3 paragraphs to explain the differences or challenges when you applied the function to your chosen dataframe.
#
# I used the baseball data set in the GitHub which contains yearID,	teamID,	lgID,	playerID and salary. I created a "summarize_data_2" to find out the average, minimum, maxmium, count and mix of the salary variable. Then, I categorized the summarized data by the different years.
#
# The only difference I can find was the "mix" variable in the summarize_data and summarize_data_2. The mix vairables are all number and able to calculate the total by using sum(), but there are all string variables and I cannot use sum() for them. Hence, I used count() to find the total number of my string variable which will give the same result.
